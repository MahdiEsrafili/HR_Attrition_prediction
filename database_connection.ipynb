# %%
from sqlalchemy import create_engine  
from sqlalchemy import Column, String,Integer 
from sqlalchemy.ext.declarative import declarative_base  
from sqlalchemy.orm import sessionmaker
import pandas as pd
import sqlalchemy

# %%
db_string = "postgres://mluser:123456789@localhost:5432/mldb"
db = create_engine(db_string)  
base = declarative_base()

# %%
conn = db.connect()

# %%
class Film(base):  
    __tablename__ = 'films'

    title = Column(String, primary_key=True)
    director = Column(String)
    year = Column(String)

# %%
Session = sessionmaker(db)  
session = Session()

base.metadata.create_all(db)

# %%
# Create 
doctor_strange = Film(title="Doctor Strange", director="Scott Derrickson", year="2016")  
session.add(doctor_strange)  
session.commit()

# %%
# Read
films = session.query(Film)  
for film in films:  
    print(film.title, film.director)
# Out:
# Doctor Strange Scott Derrickson

# %%
# Update
doctor_strange.title = "Some2016Film"  
session.commit()

# %%
# Delete
session.delete(doctor_strange)  
session.commit()

# %%
data = pd.read_csv('data/WA_Fn-UseC_-HR-Employee-Attrition.csv')
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
for c in data.columns:
    print(c)
# Out:
# Age
# Attrition
# BusinessTravel
# DailyRate
# Department
# DistanceFromHome
# Education
# EducationField
# EmployeeCount
# EmployeeNumber
# EnvironmentSatisfaction
# Gender
# HourlyRate
# JobInvolvement
# JobLevel
# JobRole
# JobSatisfaction
# MaritalStatus
# MonthlyIncome
# MonthlyRate
# NumCompaniesWorked
# Over18
# OverTime
# PercentSalaryHike
# PerformanceRating
# RelationshipSatisfaction
# StandardHours
# StockOptionLevel
# TotalWorkingYears
# TrainingTimesLastYear
# WorkLifeBalance
# YearsAtCompany
# YearsInCurrentRole
# YearsSinceLastPromotion
# YearsWithCurrManager

# %%
class train_data(base):  
    __tablename__ = 'train_data'
    __table_args__ = {'extend_existing': True}
    EmployeeID = Column(Integer, primary_key=True)
    Name = Column(String)
    Age = Column(Integer)
    Attrition = Column(String)
    BusinessTravel = Column(String)
    DailyRate = Column(Integer)
    Department = Column(String)
    DistanceFromHome = Column(Integer)
    Education = Column(Integer)
    EducationField = Column(String)
    EnvironmentSatisfaction = Column(Integer)
    Gender = Column(String)
    HourlyRate = Column(Integer)
    JobInvolvement = Column(Integer)
    JobLevel = Column(Integer)
    JobRole = Column(String)
    JobSatisfaction = Column(Integer)
    MaritalStatus = Column(String)
    MonthlyIncome = Column(Integer)
    MonthlyRate = Column(Integer)
    NumCompaniesWorked = Column(Integer)
    OverTime = Column(Integer)
    PercentSalaryHike = Column(Integer)
    PerformanceRating = Column(Integer)
    RelationshipSatisfaction = Column(Integer)
    StockOptionLevel = Column(Integer)
    TotalWorkingYears = Column(Integer)
    TrainingTimesLastYear = Column(Integer)
    WorkLifeBalance = Column(Integer)
    YearsAtCompany = Column(Integer)
    YearsInCurrentRole = Column(Integer)
    YearsSinceLastPromotion = Column(Integer)
    YearsWithCurrManager = Column(Integer)

# %%
class predict_data(base):  
    __tablename__ = 'predict_data'
    __table_args__ = {'extend_existing': True}
    EmployeeID = Column(Integer, primary_key=True)
    Name = Column(String)
    Age = Column(Integer)
    Attrition = Column(String)
    BusinessTravel = Column(String)
    DailyRate = Column(Integer)
    Department = Column(String)
    DistanceFromHome = Column(Integer)
    Education = Column(Integer)
    EducationField = Column(String)
    EnvironmentSatisfaction = Column(Integer)
    Gender = Column(String)
    HourlyRate = Column(Integer)
    JobInvolvement = Column(Integer)
    JobLevel = Column(Integer)
    JobRole = Column(String)
    JobSatisfaction = Column(Integer)
    MaritalStatus = Column(String)
    MonthlyIncome = Column(Integer)
    MonthlyRate = Column(Integer)
    NumCompaniesWorked = Column(Integer)
    OverTime = Column(Integer)
    PercentSalaryHike = Column(Integer)
    PerformanceRating = Column(Integer)
    RelationshipSatisfaction = Column(Integer)
    StockOptionLevel = Column(Integer)
    TotalWorkingYears = Column(Integer)
    TrainingTimesLastYear = Column(Integer)
    WorkLifeBalance = Column(Integer)
    YearsAtCompany = Column(Integer)
    YearsInCurrentRole = Column(Integer)
    YearsSinceLastPromotion = Column(Integer)
    YearsWithCurrManager = Column(Integer)
    Recommendation = Column(String)

# %%
# data['company'] = 'NaN'
# data.company.iloc[:400] = 'digikala'
# data.company.iloc[400:700] = 'divar'
# data.company.iloc[700:900] = 'zoomit'
# data.company.iloc[900:1000] = 'pegah'
# data.company.iloc[1000:1200] = 'facebook'
# data.company.iloc[1200:] = 'google'

# %%
data['is_sent_to_ml'] = 'FALSE'

# %%
data.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  StandardHours StockOptionLevel  TotalWorkingYears  \
# ...

# %%
data.to_sql('train2', db, if_exists= 'replace')

# %%
data_psql = pd.read_sql("select * from train2 where is_sent_to_ml='FALSE'", db)

# %%
data_psql.shape
# Out:
# (1470, 37)

# %%
data_psql.head()
# Out:
#    index  Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      0   41       Yes      Travel_Rarely       1102                   Sales
# 1      1   49        No  Travel_Frequently        279  Research & Development
# 2      2   37       Yes      Travel_Rarely       1373  Research & Development
# 3      3   33        No  Travel_Frequently       1392  Research & Development
# 4      4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  ...  \
# 0                 1          2  Life Sciences              1  ...
# 1                 8          1  Life Sciences              1  ...
# 2                 2          2          Other              1  ...
# 3                 3          4  Life Sciences              1  ...
# 4                 2          1        Medical              1  ...
#
#    StandardHours  StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  \
# ...

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'company'],
#       dtype='object')

# %%
inc_name_data = pd.read_csv('data/name_attached/train_data_incl_names.csv')
inc_name_data.drop('Unnamed: 0', 1 , inplace = True)
inc_name_data['is_sent_to_ml'] = 'FALSE'
inc_name_data['Attrition'] = 'None'
inc_name_data['recommendation'] = 'None'
inc_name_data['updated_by'] = 'BE'
inc_name_data['updated_time'] = 'None'
inc_name_data.head()
# Out:
#                 Name  Age Attrition     BusinessTravel  DailyRate  \
# 0         James Butt   41      None      Travel_Rarely       1102
# 1  Josephine Darakjy   49      None  Travel_Frequently        279
# 2         Art Venere   37      None      Travel_Rarely       1373
# 3     Lenna Paprocki   33      None  Travel_Frequently       1392
# 4     Donette Foller   27      None      Travel_Rarely        591
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
# 3  Research & Development                 3          4  Life Sciences
# 4  Research & Development                 2          1        Medical
#
#    EmployeeCount  ...  TrainingTimesLastYear  WorkLifeBalance YearsAtCompany  \
# ...

# %%
inc_name_data.to_sql('stars_train_data', conn,if_exists= 'replace')

# %%
from datetime import datetime

# %%
str(datetime.now())
# Out:
# '2020-11-10 23:27:19.375857'

# %%
inc_name_data = pd.read_csv('data/name_attached/prediction_data_incl_names.csv')
inc_name_data.drop('Unnamed: 0', 1 , inplace = True)
inc_name_data['is_sent_to_ml'] = 'FALSE'
inc_name_data['Attrition'] = 'None'
inc_name_data['recommendation'] = 'None'
inc_name_data['updated_by'] = 'BE'
inc_name_data['updated_time'] = 'None'
db_dtype = {
    'updated_time': sqlalchemy.TIMESTAMP
}
inc_name_data.head()
# Out:
#                       Name  Age     BusinessTravel  DailyRate  \
# 0                Mi Richan   42      Travel_Rarely       1147
# 1  Francoise Rautenstrauch   52      Travel_Rarely        258
# 2              Kendra Loud   37      Travel_Rarely       1462
# 3         Lourdes Bauswell   35  Travel_Frequently        200
# 4           Hannah Edmison   25      Travel_Rarely        949
#
#                Department  DistanceFromHome  Education    EducationField  \
# 0         Human Resources                10          3   Human Resources
# 1  Research & Development                 8          4             Other
# 2  Research & Development                11          3           Medical
# 3  Research & Development                18          2     Life Sciences
# 4  Research & Development                 1          3  Technical Degree
#
#    EmployeeCount  EmployeeNumber  ...  WorkLifeBalance YearsAtCompany  \
# 0              1            1408  ...                3             20
# ...

# %%
inc_name_data.to_sql('stars_prediction_data', conn,if_exists= 'replace')

# %%
metadata = sqlalchemy.MetaData()
metadata.reflect(bind = db)
# prediction_table = metadata.tables['prediction_data']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-94-2923fd0e9a0a> in <module>
#       1 metadata = sqlalchemy.MetaData()
# ----> 2 metadata.reflect(bind = db)
#       3 prediction_table = metadata.tables['prediction_data']
#
# NameError: name 'db' is not defined

# %%
t1 = prediction_table.update().where(prediction_table.c.index == 14).values({'Name' :"11sdfncrease salary"})
db.execute(t1)

# %%
data = pd.read_sql("prediction_data", db)

# %%
data.head()
# Out:
#    index                     Name  Age BusinessTravel  DailyRate  \
# 0      1  Francoise Rautenstrauch   52  Travel_Rarely        258
# 1      2              Kendra Loud   37  Travel_Rarely       1462
# 2      4           Hannah Edmison   25  Travel_Rarely        949
# 3      5                Tom Loeza   26  Travel_Rarely        652
# 4      6       Queenie Kramarczyk   29  Travel_Rarely        332
#
#                Department  DistanceFromHome  Education    EducationField  \
# 0  Research & Development                 8          4             Other
# 1  Research & Development                11          3           Medical
# 2  Research & Development                 1          3  Technical Degree
# 3  Research & Development                 7          3             Other
# 4         Human Resources                17          3             Other
#
#    EmployeeCount  ...  WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# ...

# %%
import chl_app_config

# %%
chl_app_config.db_string
# Out:
# 'postgres://pjohhflfynacwy:9a5ddc83ee5a46b0a7b115784e3b62d6f57f6dc5fed97cd2bb2cb7f2316c7b12@ec2-54-75-150-32.eu-west-1.compute.amazonaws.com:5432/d4c9gffpjmtgvc'

# %%
 redict_data = pd.read_sql("select * from prediction_data where is_sent_to_ml='FALSE'", db)

# %%
redict_data
# Out:
# Empty DataFrame
# Columns: [index, Name, Age, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, EmployeeCount, EmployeeNumber, EnvironmentSatisfaction, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyIncome, MonthlyRate, NumCompaniesWorked, Over18, OverTime, PercentSalaryHike, PerformanceRating, RelationshipSatisfaction, StandardHours, StockOptionLevel, TotalWorkingYears, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager, is_sent_to_ml, Attrition, recommendation, updated_by, updated_time]
# Index: []
#
# [0 rows x 41 columns]

# %%
user = 'qiyetmaoqcmast'
pswd = 'e95e1fe4987ce78244876261bed606741ae6229b47ddd050bcbe8093f05a5486'
port = 5432
host = 'ec2-54-75-150-32.eu-west-1.compute.amazonaws.com'
hedb_string = f"postgres://{user}:{pswd}@{host}:{port}/{database}"
he_db = create_engine(hedb_string)

# %%
heconn = he_db.connect()

# %%
predict_data = pd.read_sql('select * from prediction_data where is_delete=0', heconn)
predict_data.head()
# Out:
#                                      id  created_by            created_time  \
# 0  f1932e21-2980-499e-b967-87a60db2a01d  superadmin 2020-11-11 14:29:28.916
# 1  fec77e74-710c-4938-9db8-ac7f736ed6c9  superadmin 2020-11-11 14:29:28.916
# 2  419ae1d2-6b56-43ac-ba85-a7423d840400  superadmin 2020-11-11 14:29:28.916
# 3  3157cf1a-8582-4a20-ae60-82779925525f  superadmin 2020-11-11 14:29:28.916
# 4  ecf576b7-7886-4e36-b02d-0790049d1adf  superadmin 2020-11-11 14:29:28.916
#
#    is_delete        updated_by               updated_time  age  \
# 0          0  machine learning 2020-11-12 13:19:42.083666   55
# 1          0  machine learning 2020-11-12 13:19:42.089613   36
# 2          0  machine learning 2020-11-12 13:19:42.094758   31
# 3          0  machine learning 2020-11-12 13:19:42.100203   30
# 4          0  machine learning 2020-11-12 13:19:42.105579   31
#
#      business_travel  daily_rate              department  ...  \
# 0      Travel_Rarely        1136  Research & Development  ...
# ...

# %%
type(predict_data.iloc[0].is_delete)
# Out:
# numpy.int64

# %%
predict_data[predict_data.id=='6d4f3b91-0cc7-4ef2-93e6-de7db09bbddf']
# Out:
#                                        id  created_by            created_time  \
# 470  6d4f3b91-0cc7-4ef2-93e6-de7db09bbddf  superadmin 2020-11-11 14:29:28.914
#
#      is_delete        updated_by               updated_time  age  \
# 470          0  machine learning 2020-11-12 16:24:07.468941   42
#
#     business_travel  daily_rate       department  ...  \
# 470   Travel_Rarely        1147  Human Resources  ...
#
#      training_times_last_year  work_life_balance years_at_company  \
# 470                         5                  3               20
#
#      years_in_current_role  years_since_last_promotion  \
# 470                      7                           0
#
#      years_with_curr_manager attrition  employee_id  recommendations  \
# 470                        9      True          999              rec
#
#      is_sent_to_ml
# 470           True
#
# [1 rows x 45 columns]

# %%
predict_data[predict_data.attrition == True]
# Out:
# Empty DataFrame
# Columns: [id, created_by, created_time, is_delete, updated_by, updated_time, age, business_travel, daily_rate, department, distance_from_home, education, education_field, employee_count, employee_number, environment_satisfaction, gender, hourly_rate, job_involvement, job_level, job_role, job_satisfaction, marital_status, monthly_income, monthly_rate, name, num_companies_worked, over18, over_time, percent_salary_hike, performance_rating, relationship_satisfaction, standard_hours, stock_option_level, total_working_years, training_times_last_year, work_life_balance, years_at_company, years_in_current_role, years_since_last_promotion, years_with_curr_manager, attrition, employee_id, recommendations, is_sent_to_ml]
# Index: []
#
# [0 rows x 45 columns]

# %%
metadata = sqlalchemy.MetaData()
metadata.reflect(bind = he_db)
prediction_table = metadata.tables['prediction_data']

# %%
q = prediction_table.update().where(prediction_table.c.id == '6d4f3b91-0cc7-4ef2-93e6-de7db09bbddf').values({
            'attrition' : True,
            'recommendations': 'rec',
            'is_sent_to_ml': True,
            'updated_by': 'machine learning',
            'updated_time' : pd.to_datetime(datetime.now())
            })
heconn.execute(q)

# %%
predict_data.columns
# Out:
# Index(['id', 'created_by', 'created_time', 'is_delete', 'updated_by',
#        'updated_time', 'age', 'business_travel', 'daily_rate', 'department',
#        'distance_from_home', 'education', 'education_field', 'employee_count',
#        'employee_number', 'environment_satisfaction', 'gender', 'hourly_rate',
#        'job_involvement', 'job_level', 'job_role', 'job_satisfaction',
#        'marital_status', 'monthly_income', 'monthly_rate', 'name',
#        'num_companies_worked', 'over18', 'over_time', 'percent_salary_hike',
#        'performance_rating', 'relationship_satisfaction', 'standard_hours',
#        'stock_option_level', 'total_working_years', 'training_times_last_year',
#        'work_life_balance', 'years_at_company', 'years_in_current_role',
#        'years_since_last_promotion', 'years_with_curr_manager', 'attrition',
#        'employee_id', 'recommendations', 'is_sent_to_ml'],
#       dtype='object')

# %%
train_data = pd.read_sql('train_data', heconn)
train_data.head()
# Out:
#                                      id  created_by            created_time  \
# 0  e2bd81cd-73a2-4a92-8261-448a28e818ad  superadmin 2020-11-11 14:29:14.256
# 1  c974d91b-807d-4514-bd34-e0637fccbfe0  superadmin 2020-11-11 14:29:14.266
# 2  cf9d5144-6eae-4186-9d6b-754eca598931  superadmin 2020-11-11 14:29:14.266
# 3  86504a6e-25a8-4194-b41a-f4c4d3d1d1a4  superadmin 2020-11-11 14:29:14.266
# 4  1d7734a7-e34e-49ad-add2-cdadac2601dc  superadmin 2020-11-11 14:29:14.266
#
#    is_delete updated_by            updated_time  age    business_travel  \
# 0          0       None 2020-11-11 14:29:14.256   41      Travel_Rarely
# 1          0       None 2020-11-11 14:29:14.266   49  Travel_Frequently
# 2          0       None 2020-11-11 14:29:14.266   37      Travel_Rarely
# 3          0       None 2020-11-11 14:29:14.266   33  Travel_Frequently
# 4          0       None 2020-11-11 14:29:14.266   27      Travel_Rarely
#
#    daily_rate              department  ...  total_working_years  \
# ...

# %%
train_data[train_data.id.isin(train_data.iloc[:4].id.values)]
# Out:
#                                      id  created_by            created_time  \
# 0  e2bd81cd-73a2-4a92-8261-448a28e818ad  superadmin 2020-11-11 14:29:14.256
# 1  c974d91b-807d-4514-bd34-e0637fccbfe0  superadmin 2020-11-11 14:29:14.266
# 2  cf9d5144-6eae-4186-9d6b-754eca598931  superadmin 2020-11-11 14:29:14.266
# 3  86504a6e-25a8-4194-b41a-f4c4d3d1d1a4  superadmin 2020-11-11 14:29:14.266
#
#    is_delete updated_by            updated_time  age    business_travel  \
# 0          0       None 2020-11-11 14:29:14.256   41      Travel_Rarely
# 1          0       None 2020-11-11 14:29:14.266   49  Travel_Frequently
# 2          0       None 2020-11-11 14:29:14.266   37      Travel_Rarely
# 3          0       None 2020-11-11 14:29:14.266   33  Travel_Frequently
#
#    daily_rate              department  ...  total_working_years  \
# 0        1102                   Sales  ...                    8
# 1         279  Research & Development  ...                   10
# ...

# %%
train_i = train_data.set_index('id')

# %%
train_i.head()
# Out:
#                                       created_by            created_time  \
# id
# e2bd81cd-73a2-4a92-8261-448a28e818ad  superadmin 2020-11-11 14:29:14.256
# c974d91b-807d-4514-bd34-e0637fccbfe0  superadmin 2020-11-11 14:29:14.266
# cf9d5144-6eae-4186-9d6b-754eca598931  superadmin 2020-11-11 14:29:14.266
# 86504a6e-25a8-4194-b41a-f4c4d3d1d1a4  superadmin 2020-11-11 14:29:14.266
# 1d7734a7-e34e-49ad-add2-cdadac2601dc  superadmin 2020-11-11 14:29:14.266
#
#                                       is_delete updated_by  \
# id
# e2bd81cd-73a2-4a92-8261-448a28e818ad          0       None
# c974d91b-807d-4514-bd34-e0637fccbfe0          0       None
# cf9d5144-6eae-4186-9d6b-754eca598931          0       None
# 86504a6e-25a8-4194-b41a-f4c4d3d1d1a4          0       None
# 1d7734a7-e34e-49ad-add2-cdadac2601dc          0       None
#
#                                                 updated_time  age  \
# id
# e2bd81cd-73a2-4a92-8261-448a28e818ad 2020-11-11 14:29:14.256   41
# ...

# %%
train_i.iloc[0:5]
# Out:
#                                       created_by            created_time  \
# id
# e2bd81cd-73a2-4a92-8261-448a28e818ad  superadmin 2020-11-11 14:29:14.256
# c974d91b-807d-4514-bd34-e0637fccbfe0  superadmin 2020-11-11 14:29:14.266
# cf9d5144-6eae-4186-9d6b-754eca598931  superadmin 2020-11-11 14:29:14.266
# 86504a6e-25a8-4194-b41a-f4c4d3d1d1a4  superadmin 2020-11-11 14:29:14.266
# 1d7734a7-e34e-49ad-add2-cdadac2601dc  superadmin 2020-11-11 14:29:14.266
#
#                                       is_delete updated_by  \
# id
# e2bd81cd-73a2-4a92-8261-448a28e818ad          0       None
# c974d91b-807d-4514-bd34-e0637fccbfe0          0       None
# cf9d5144-6eae-4186-9d6b-754eca598931          0       None
# 86504a6e-25a8-4194-b41a-f4c4d3d1d1a4          0       None
# 1d7734a7-e34e-49ad-add2-cdadac2601dc          0       None
#
#                                                 updated_time  age  \
# id
# e2bd81cd-73a2-4a92-8261-448a28e818ad 2020-11-11 14:29:14.256   41
# ...

# %%
train_i[train_i.index.isin(train_i.iloc[0:5].index)]
# Out:
#                                       created_by            created_time  \
# id
# e2bd81cd-73a2-4a92-8261-448a28e818ad  superadmin 2020-11-11 14:29:14.256
# c974d91b-807d-4514-bd34-e0637fccbfe0  superadmin 2020-11-11 14:29:14.266
# cf9d5144-6eae-4186-9d6b-754eca598931  superadmin 2020-11-11 14:29:14.266
# 86504a6e-25a8-4194-b41a-f4c4d3d1d1a4  superadmin 2020-11-11 14:29:14.266
# 1d7734a7-e34e-49ad-add2-cdadac2601dc  superadmin 2020-11-11 14:29:14.266
#
#                                       is_delete updated_by  \
# id
# e2bd81cd-73a2-4a92-8261-448a28e818ad          0       None
# c974d91b-807d-4514-bd34-e0637fccbfe0          0       None
# cf9d5144-6eae-4186-9d6b-754eca598931          0       None
# 86504a6e-25a8-4194-b41a-f4c4d3d1d1a4          0       None
# 1d7734a7-e34e-49ad-add2-cdadac2601dc          0       None
#
#                                                 updated_time  age  \
# id
# e2bd81cd-73a2-4a92-8261-448a28e818ad 2020-11-11 14:29:14.256   41
# ...

# %%
train_i.iloc[0]['id']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4410             try:
# -> 4411                 return libindex.get_value_at(s, key)
#    4412             except IndexError:
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_at()
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.validate_indexer()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-71-84dafe37337d> in <module>
# ----> 1 train_i.iloc[0]['id']
#
# ...

# %%
train_i[train_i['id'].isin(train_i.iloc[:5]['id'])]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'id'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-9ff34110a46c> in <module>
# ...

# %%
tra

# %%
train_data.iloc[0]['updated_time']
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
from datetime import datetime

# %%
pd.to_datetime(datetime.now())
# Out:
# Timestamp('2020-11-12 14:10:15.673011')

# %%
type(train_data.iloc[0]['is_sent_to_ml'])
# Out:
# numpy.bool_

# %%
True
# Out:
# True

# %%
bool(1)
# Out:
# True

# %%
train_data.columns
# Out:
# Index(['id', 'created_by', 'created_time', 'is_delete', 'updated_by',
#        'updated_time', 'age', 'business_travel', 'daily_rate', 'department',
#        'distance_from_home', 'education', 'education_field', 'employee_count',
#        'employee_number', 'environment_satisfaction', 'gender', 'hourly_rate',
#        'job_involvement', 'job_level', 'job_role', 'job_satisfaction',
#        'marital_status', 'monthly_income', 'monthly_rate', 'name',
#        'num_companies_worked', 'over18', 'over_time', 'percent_salary_hike',
#        'performance_rating', 'relationship_satisfaction', 'standard_hours',
#        'stock_option_level', 'total_working_years', 'training_times_last_year',
#        'work_life_balance', 'years_at_company', 'years_in_current_role',
#        'years_since_last_promotion', 'years_with_curr_manager', 'attrition',
#        'employee_id', 'is_sent_to_ml'],
#       dtype='object')

# %%
data = pd.read_csv('data/name_attached/train_data_incl_names.csv')
data.drop('Unnamed: 0', 1 , inplace = True)
data['is_sent_to_ml'] = 'FALSE'
data['Attrition'] = 'None'
data['recommendation'] = 'None'
data['updated_by'] = 'BE'
data['updated_time'] = 'None'
data.set_index('EmployeeNumber',inplace = True)
data.head()
# Out:
#                              Name  Age Attrition     BusinessTravel  \
# EmployeeNumber
# 1                      James Butt   41      None      Travel_Rarely
# 2               Josephine Darakjy   49      None  Travel_Frequently
# 4                      Art Venere   37      None      Travel_Rarely
# 5                  Lenna Paprocki   33      None  Travel_Frequently
# 7                  Donette Foller   27      None      Travel_Rarely
#
#                 DailyRate              Department  DistanceFromHome  \
# EmployeeNumber
# 1                    1102                   Sales                 1
# 2                     279  Research & Development                 8
# 4                    1373  Research & Development                 2
# 5                    1392  Research & Development                 3
# 7                     591  Research & Development                 2
#
#                 Education EducationField  EmployeeCount  ...  \
# ...

# %%
sample = data.iloc[:5]
sample_json = sample.to_json()
sample_json
# Out:
# '{"Name":{"1":"James Butt","2":"Josephine Darakjy","4":"Art Venere","5":"Lenna Paprocki","7":"Donette Foller"},"Age":{"1":41,"2":49,"4":37,"5":33,"7":27},"Attrition":{"1":"None","2":"None","4":"None","5":"None","7":"None"},"BusinessTravel":{"1":"Travel_Rarely","2":"Travel_Frequently","4":"Travel_Rarely","5":"Travel_Frequently","7":"Travel_Rarely"},"DailyRate":{"1":1102,"2":279,"4":1373,"5":1392,"7":591},"Department":{"1":"Sales","2":"Research & Development","4":"Research & Development","5":"Research & Development","7":"Research & Development"},"DistanceFromHome":{"1":1,"2":8,"4":2,"5":3,"7":2},"Education":{"1":2,"2":1,"4":2,"5":4,"7":1},"EducationField":{"1":"Life Sciences","2":"Life Sciences","4":"Other","5":"Life Sciences","7":"Medical"},"EmployeeCount":{"1":1,"2":1,"4":1,"5":1,"7":1},"EnvironmentSatisfaction":{"1":2,"2":3,"4":4,"5":4,"7":1},"Gender":{"1":"Female","2":"Male","4":"Male","5":"Female","7":"Male"},"HourlyRate":{"1":94,"2":61,"4":92,"5":56,"7":40},"JobInvolvement":{"1":
# ...

# %%
x = pd.DataFrame(dj)

# %%
x
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41      None      Travel_Rarely       1102                   Sales
# 1   49      None  Travel_Frequently        279  Research & Development
# 2   37      None      Travel_Rarely       1373  Research & Development
# 3   33      None  Travel_Frequently       1392  Research & Development
# 4   27      None      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# ...

# %%
pd.read_csv('upload_dir/json_sample.csv')
# Out:
#    Unnamed: 0               Name  Age Attrition     BusinessTravel  DailyRate  \
# 0           0         James Butt   41      None      Travel_Rarely       1102
# 1           1  Josephine Darakjy   49      None  Travel_Frequently        279
# 2           2         Art Venere   37      None      Travel_Rarely       1373
# 3           3     Lenna Paprocki   33      None  Travel_Frequently       1392
# 4           4     Donette Foller   27      None      Travel_Rarely        591
#
#                Department  DistanceFromHome  Education EducationField  ...  \
# 0                   Sales                 1          2  Life Sciences  ...
# 1  Research & Development                 8          1  Life Sciences  ...
# 2  Research & Development                 2          2          Other  ...
# 3  Research & Development                 3          4  Life Sciences  ...
# 4  Research & Development                 2          1        Medical  ...
#
# ...

# %%
list(set(['a','b'])& set(['a','c']))
# Out:
# ['a']

# %%
pd.read_sql('stars_train_data', conn)
# Out:
#    index               Name  Age Attrition     BusinessTravel  DailyRate  \
# 0      1  Josephine Darakjy   49      None  Travel_Frequently        279
# 1      4     Donette Foller   27      None      Travel_Rarely        591
# 2      1  Josephine Darakjy   49      None  Travel_Frequently        279
# 3      4     Donette Foller   27      None      Travel_Rarely        591
# 4      0         James Butt   41      None      Travel_Rarely       1102
# 5      1  Josephine Darakjy   49      None  Travel_Frequently        279
# 6      2         Art Venere   37      None      Travel_Rarely       1373
# 7      3     Lenna Paprocki   33      None  Travel_Frequently       1392
# 8      4     Donette Foller   27      None      Travel_Rarely        591
# 9      0         James Butt   41      None      Travel_Rarely       1102
# 10     1  Josephine Darakjy   49      None  Travel_Frequently        279
# 11     2         Art Venere   37      None      Travel_Rarely       1373
# ...

# %%
metadata = sqlalchemy.MetaData()
metadata.reflect(bind = conn)
db_train_data = metadata.tables['stars_train_data']

# %%
q = db_train_data.delete().where(db_train_data.c.Name.in_(['Art Venere', 'Lenna Paprocki']))
conn.execute(q)

# %%
q = db_train_data.select().limit(2)
conn.execute(q)

# %%
type([4]) == list
# Out:
# True

# %%
r = {
    "data" : [2]
}

# %%
r['data']
# Out:
# [2]

# %%
list(set([1,3]) - set(None))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-f7718942ecf3> in <module>
# ----> 1 list(set([1,3]) - set(None))
#
# TypeError: 'NoneType' object is not iterable

# %%
a = None

# %%
if a:
    print('yess')
