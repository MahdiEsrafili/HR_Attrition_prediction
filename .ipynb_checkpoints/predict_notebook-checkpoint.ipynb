# %%
import joblib
from ModifiedLabelEncoder import ModifiedLabelEncoder
import pandas as pd
from IPython.display import display
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv('data/WA_Fn-UseC_-HR-Employee-Attrition.csv')
data.set_index('EmployeeNumber', inplace =True)
data.head(2)
# Out:
#                 Age Attrition     BusinessTravel  DailyRate  \
# EmployeeNumber
# 1                41       Yes      Travel_Rarely       1102
# 2                49        No  Travel_Frequently        279
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 1                                Sales                 1          2
# 2               Research & Development                 8          1
#
#                EducationField  EmployeeCount  EnvironmentSatisfaction  ...  \
# EmployeeNumber                                                         ...
# 1               Life Sciences              1                        2  ...
# 2               Life Sciences              1                        3  ...
#
#                RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# EmployeeNumber
# 1                                     1             80                 0
# 2                                     4             80                 1
#
# ...

# %%
data.iloc[0].DailyRate.dtype
# Out:
# dtype('int64')

# %%
model_pipe = joblib.load('model_pipe.joblib')
le_pipe = joblib.load('le_pipe.joblib')

# %%
sample = data.iloc[:1]
sample
# Out:
#                 Age Attrition BusinessTravel  DailyRate Department  \
# EmployeeNumber
# 1                41       Yes  Travel_Rarely       1102      Sales
#
#                 DistanceFromHome  Education EducationField  EmployeeCount  \
# EmployeeNumber
# 1                              1          2  Life Sciences              1
#
#                 EnvironmentSatisfaction  ... RelationshipSatisfaction  \
# EmployeeNumber                           ...
# 1                                     2  ...                        1
#
#                 StandardHours  StockOptionLevel  TotalWorkingYears  \
# EmployeeNumber
# 1                          80                 0                  8
#
#                TrainingTimesLastYear  WorkLifeBalance YearsAtCompany  \
# EmployeeNumber
# 1                                  0                1              6
#
#                 YearsInCurrentRole  YearsSinceLastPromotion  \
# EmployeeNumber
# 1                                4                        0
#
# ...

# %%
x = le_pipe.transform(sample.drop('Attrition', 1))
model_pipe.predict(x)
# Out:
# array([1], dtype=int64)

# %%
model_pipe.classes_
# Out:
# array([0, 1], dtype=int64)

# %%
data.sample(n = 100).to_csv('data/sample.csv')

# %%
x = data.sample(1)
display(x)
x = le_pipe.transform(x.drop('Attrition', 1))
print(model_pipe.predict(x))
# Out:
#                 Age Attrition BusinessTravel  DailyRate  \
# EmployeeNumber
# 991              31       Yes     Non-Travel        335
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 991             Research & Development                 9          2
#
#                EducationField  EmployeeCount  EnvironmentSatisfaction Gender  \
# EmployeeNumber
# 991                   Medical              1                        3   Male
#
#                 HourlyRate  JobInvolvement  JobLevel             JobRole  \
# EmployeeNumber
# 991                     46               2         1  Research Scientist
#
#                 JobSatisfaction MaritalStatus  MonthlyIncome  MonthlyRate  \
# EmployeeNumber
# 991                           1        Single           2321        10322
#
#                 NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# EmployeeNumber
# 991                              0      Y      Yes                 22
#
# ...

# %%
data.sample(1).Attrition.item()
# Out:
# 'Yes'
